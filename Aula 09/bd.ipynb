# %% [markdown]
# Importando Libs

# %%
import pyodbc
import pandas as pd

# %% [markdown]
# Criando conexão

# %%
# conn = pyodbc.connect(
#     "DRIVER={ODBC Driver 17 for SQL Server};" \
#     "SERVER=den1.mssql7.gear.host;" \ 
#     "DATABASE=vendasbicyclon;"  \
#     "UID=vendasbicyclon;"     \
#     "PWD=senha@clarify;"       \
#     "MARS_Connection=Yes"
# )

# %%
conn = pyodbc.connect(
    "DRIVER={SQL Server};"\
    "SERVER=den1.mssql7.gear.host;"\
    "DATABASE=vendasbicyclon;"\
    "UID=vendasbicyclon;"\
    "PWD=senha@clarify;" \
    'MARS_Connnection=yes;'
)

# %%
# FUNÇÃO EXECUTAR QUERY 

def exe_query(query):
    return  pd.read_sql(query, conn)

lista_resposta = []
def exe_varias_querys(*args):
    for consulta in args:
        lista_resposta.append(pd.read_sql(consulta, conn))
    return lista_resposta

# %%
query = """
SELECT
    TABLE_SCHEMA,
    TABLE_NAME
        FROM INFORMATION_SCHEMA.TABLES
        WHERE TABLE_TYPE = 'BASE TABLE'
        ORDER BY TABLE_SCHEMA, TABLE_NAME
"""

df_tabelas = pd.read_sql(query, conn)
# Out:
# C:\Users\fernando.cremm\AppData\Local\Temp\ipykernel_28208\398176498.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_tabelas = pd.read_sql(query, conn)

# %%
df_tabelas
# Out:
#   TABLE_SCHEMA      TABLE_NAME
# 0          dbo        clientes
# 1          dbo     itensPedido
# 2          dbo  linhasProdutos
# 3          dbo         pedidos
# 4          dbo        produtos
# 5          dbo       regionais
# 6          dbo     sysdiagrams
# 7          dbo      vendedores

# %% [markdown]
# Nome dos clientes

# %%
query = "SELECT * FROM clientes"
df_clientes = pd.read_sql(query, conn)
df_clientes.head()

nomes = df_clientes['nomeCliente']
nomes
# Out:
# C:\Users\fernando.cremm\AppData\Local\Temp\ipykernel_28208\645874650.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_clientes = pd.read_sql(query, conn)
# 0           Velocycle Emporium
# 1           Pedal & Gear Haven
# 2      CicloFusion Marketplace
# 3           BiciMondo Ventures
# 4     SpinScape Bikes & Beyond
# 5           CyclaVista Cyclery
# 6    RollRight Wheels Emporium
# 7          GearSpin Provisions
# 8                BikeHub Oasis
# 9          PedalCraft Boutique
# Name: nomeCliente, dtype: str

# %% [markdown]
# Produtos com valor > 2000 e descrição preenchida

# %%
query = """
    SELECT * FROM produtos  
    where precoUnitario >= 2000
"""
df_produtos = pd.read_sql(query, conn)
df_produtos.head()

produtos = df_produtos['nomeProduto']
produtos
# Out:
# C:\Users\fernando.cremm\AppData\Local\Temp\ipykernel_28208\3427142904.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_produtos = pd.read_sql(query, conn)
# 0          Summit Seeker 2000
# 1         Velocity Racer 3000
# 2        E-Power Cruiser 6000
# 3      Junior Adventurer 8000
# 4    Expedition Voyager 11000
# Name: nomeProduto, dtype: str

# %%
query_colunas = """
SELECT
      TABLE_SCHEMA,
      TABLE_NAME,
      COLUMN_NAME,
      DATA_TYPE,
      IS_NULLABLE
          FROM INFORMATION_SCHEMA.COLUMNS
          ORDER BY TABLE_SCHEMA, TABLE_NAME, ORDINAL_POSITION
"""

exe_query(query_colunas)
# Out:
# C:\Users\fernando.cremm\AppData\Local\Temp\ipykernel_28208\2641567547.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return  pd.read_sql(query, conn)
#    TABLE_SCHEMA      TABLE_NAME            COLUMN_NAME  DATA_TYPE IS_NULLABLE
# 0           dbo        clientes              idCliente        int          NO
# 1           dbo        clientes            nomeCliente    varchar          NO
# 2           dbo        clientes          cidadeCliente    varchar         YES
# 3           dbo     itensPedido                 idItem        int          NO
# 4           dbo     itensPedido               idPedido        int          NO
# 5           dbo     itensPedido              idProduto        int          NO
# 6           dbo     itensPedido             quantidade        int          NO
# ...

# %%
lista_resposta
# Out:
# []
