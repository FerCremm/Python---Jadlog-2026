# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong><br/><br/><br/><br/>
#         Funções
#     </strong>
# </p>

# %%
# Simples

def falaComigo():
    print('Eae Meu Parceiro')

def soma2valores():
    print(10+20)

falaComigo()
soma2valores()
# Out:
# Eae Meu Parceiro
# 30

# %%
# Com retorno

def falaComigo():
    return 'Eae'

def soma2valores():
    return 10+20

print(falaComigo())

print(soma2valores() * 100)
# Out:
# Eae
# 3000

# %%
# Com parâmetros e argumentos

def cantar_parabens(nome):
    return f'Eae, {nome}! Parabens para vc HAHAHAHA'

cantar_parabens(input("Aniversariante: "))

def soma2valores(num1, num2):
    return num1 + num2 

soma2valores(num1=15, num2=30)
soma2valores(15,30)
# Out:
# 45

# %%
def geradorDeDesconto(valor, desconto = 0.1):
    """
        Explicar: Função calcula um desconto por % inserido

        Valor: Pode ser float ou int

        desconto: Precisa ser informado em decimal
    """
    return valor * desconto

geradorDeDesconto(100)
# Out:
# 10.0

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong><br/><br/><br/><br/>
#         Bibliotecas
#     </strong>
# </p>

# %%
import time
from random import randint

print('Espera um pouco')
time.sleep(2)
print('Agora sim')
# Out:
# Espera um pouco
# Agora sim

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong>
#         Instalando bibliotecas
#     </strong>
# </p>

# %%
#!pip freeze
#!pip install nome de biblioteca
#!pip uninstall nome da biblioteca

#pip freeze > requirements.txt
# Out:
#   Cell In[100], line 5
#     pip freeze > requirements.txt
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong></br></br></br></br>
#         DATETIME
#     </strong>
# </p>

# %%
#import datetime                                          #https://docs.python.org/pt-br/3.6/library/datetime.html

from datetime import datetime

import locale
locale.setlocale(locale.LC_TIME, 'pt_BR.UTF-8')
locale.setlocale(locale.LC_TIME, 'portuguese')

datetime.today()
hoje = datetime.now().strftime("%d/%m/%Y, %H:%M:%S")

hoje
# Out:
# '30/01/2026, 09:10:43'

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong></br></br></br></br>
#         Criando arquivos com python
#     </strong>
# </p>

# %%
with open ("teste.txt",mode='w', encoding="UTF8") as arquivo: #r -> informa que não e um comando e parte de um texto
                                                              #as -> olha o que tem atras dele #encoding -> Corrige 
                                                              # letra a alimenta o arquivo #letra W substitui o conteudo ambos criam o arquivo
   
       arquivo.write("Fernando\n".title())                    #\n -> pula linha

# %%
with open ("teste.txt", encoding="UTF8") as arquivo:
    #dados = arquivo.read()                                    #read faz a leitura (caso eu so vá ler jogo no print se eu for acompanhar eu jogo na variavel)
    dados = arquivo.readlines()

for linha in dados:
    print(linha.replace("\n", ""))                             #replace substitui(dentro do parentes o parente e o que eu quero encontrar e a segunda e o que eu quero colocar no local)
# Out:
# Fernando
# Geovana
# Alvaro

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong>
#         lendo arquivos com python
#     </strong>
# </p>

# %%
with open ("teste.txt", encoding="UTF8") as arquivo:
    dados = arquivo.readlines()

for linha in dados:
    print(linha.replace("\n", ""))
# Out:
# Fernando
# Geovana
# Alvaro

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong></br></br></br></br>
#         JSON
#     </strong>
# </p>

# %%
import json

try:
    with open(r"dados\contas.json" ,'r' , encoding="UTF8") as arquivo:
        contas = json.load(arquivo)

except FileNotFoundError as erro:
    print(erro)

#finally:
    #print('Geovana')

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong><br/><br/><br/><br/>
#         Tratamento
#     </strong>
# </p>

# %%
# Converter data em texto para data real (datetime)

from datetime import datetime 

dados
# Out:
# ['Fernando\n', 'Geovana\n', 'Alvaro']

# %%
from datetime import datetime 

for conta in contas:                                                                  #SINGULAR E DICIONARIO - PLUARAL E LISTA
    conta['vencimento'] = datetime.strptime(conta['vencimento'].strip(), "%d/%m/%Y")  #ESSA LINHA CONVERTE A DATA EM QUALQUER FORMATAÇÃO PARA O PADRÃO


#contas[0]['vencimento'] = datetime.strftime('%d/%m/%Y')

# %%
# Verificando conversão

contas[0]['vencimento']
# Out:
# datetime.datetime(2026, 1, 27, 0, 0)

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong><br/><br/><br/><br/>
#         Análise (Vencimentos)
#     </strong>
# </p>

# %%
# Quantas contas estão vencidas?

from datetime import datetime

hoje = datetime.today()
contas_vencidas = []

for conta in contas:
    if conta['vencimento'] < hoje and conta['status'] == "Em aberto" and conta['tipo'] == "Pagar":
        contas_vencidas.append(conta)

len(contas_vencidas)
# Out:
# 777

# %%
# Total em contas vencidas?

total_vencido = 0

for contas in contas_vencidas:
    # total_vencido = total_vencido + conta['valor']
    total_vencido += conta['valor']

round(total_vencido,2)
# Out:
# 2313439.8

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong><br/><br/><br/><br/>
#         Análise (pagar e receber)
#     </strong>
# </p>

# %%
# Quantas contas temos neste arquivo


# Acessando campo valor


# Acessandos todos os valores das 5 primeiras contas

# %%
# Separando contas a pagar e receber
