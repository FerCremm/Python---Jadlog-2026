# %% [markdown]
# Importando bibliotecas

# %%
import os
import smtplib
import shutil
import pyautogui
import pywhatkit as kit
from time import sleep
from datetime import datetime
from email.message import EmailMessage
import win32com.client as win32

# %% [markdown]
# Organizando arquivos

# %%
arquivo_excel = "contas_processadas.xlsx"

pasta_base = "base"

# %% [markdown]
# Verificando se o arquivo existe

# %%
import os

if not os.path.exists(arquivo_excel):
    raise FileNotFoundError("Arquivo não localizado, verifique se o download foi concluído")

print("Arquivo encontrado")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 4
#       1 import os
#       3 if not os.path.exists(arquivo_excel):
# ----> 4     raise FileNotFoundError("Arquivo não localizado, verifique se o download foi concluído")
#       6 print("Arquivo encontrado")
#
# FileNotFoundError: Arquivo não localizado, verifique se o download foi concluído

# %% [markdown]
# Criando a pasta base dentro da pasta Aula 04

# %%
if not os.path.exists(pasta_base):
    os.makedirs(pasta_base)
    print('Pasta criada com sucesso')

else:
    print('Pasta Base já existe')
# Out:
# Pasta Base já existe

# %% [markdown]
# Movendo arquivo para dentro da pasta Base

# %%
destino = os.path.join(pasta_base, os.path.basename(arquivo_excel))

if not os.path.exists(destino):
    shutil.move(arquivo_excel, destino)
    print ('Arquivo movido com sucesso!')

else:
    print('Arquivo já existe na pasta base')
# Out:
# Arquivo já existe na pasta base

# %% [markdown]
# Criando corpo do Email

# %%
hoje = datetime.now().strftime("%d . %m . %Y | Hora %H:%M")  #| (data)
hoje

corpo_email = f"""
Platão, 

A realidade esta sendo moldada pela palavra e o pensamento em linguagem de codigos, me sinto aprendendo a ser um amo da caverna.

Dito isso, segue data de processamento: {hoje}

Abs, 
Fernando Cremm

"""

# %% [markdown]
# Configurando OUTLOOK

# %%
outlook = win32.Dispatch('Outlook.Application')

email = outlook.CreateItem(0)

email.To = 'geovanaresendeoliveira@gmail.com'
email.subject = 'Relatório seculo 21 e contas processadas de Janeiro'
email.Body = corpo_email

email.attachments.Add(
    r"C:\Users\fernando.cremm\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Curso Python1\Aula 04\base\contas_processadas.xlsx"
)

email.attachments.Add(
    r"C:\Users\fernando.cremm\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Curso Python1\Aula 04\base\platao.png"
)

email.Send()
print('Email enviado com sucesso!')
# Out:
# Email enviado com sucesso!

# %% [markdown]
# Alerta WhatsApp

# %%
telefone = "+5511974153048"

mensagem = "Agora a caverna esta de ZapZap, Relatorio enviado"

kit.sendwhatmsg_instantly(
    telefone,
    mensagem, 
    wait_time=20,
    tab_close=False
)


sleep(2)
pyautogui.press("enter")
print("Mensagem enviada ")
# Out:
# Mensagem enviada

# %% [markdown]
# Criando executável

# %%
#!pip install pyinstaller 
#!jupyter nbconvert --to script projeto.ipynb
#!pyinstaller --onefile projeto.py
# Out:
# [NbConvertApp] Converting notebook projeto.ipynb to script
# [NbConvertApp] Writing 2398 bytes to projeto.py
# 226 INFO: PyInstaller: 6.18.0, contrib hooks: 2026.0
# 226 INFO: Python: 3.12.10
# 434 INFO: Platform: Windows-11-10.0.26200-SP0
# 434 INFO: Python environment: C:\Users\fernando.cremm\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Curso Python1\Aula 01\.venv
# 437 INFO: wrote c:\Users\fernando.cremm\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Curso Python1\Aula 04\projeto.spec
# 451 INFO: Module search paths (PYTHONPATH):
# ['c:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de '
#  'Trabalho\\Curso Python1\\Aula 01\\.venv\\Scripts\\pyinstaller.exe',
#  'C:\\Program '
#  'Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\\python312.zip',
#  'C:\\Program '
#  'Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\\DLLs',
#  'C:\\Program '
#  'Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\\Lib',
#  'C:\\Program '
#  'Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0',
#  'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de '
#  'Trabalho\\Curso Python1\\Aula 01\\.venv',
#  'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de '
#  'Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages',
#  'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de '
#  'Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\win32',
#  'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de '
#  'Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\win32\\lib',
#  'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de '
#  'Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\Pythonwin',
#  'c:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de '
#  'Trabalho\\Curso Python1\\Aula 04']
# 1312 INFO: checking Analysis
# 1312 INFO: Building Analysis because Analysis-00.toc is non existent
# 1312 INFO: Looking for Python shared library...
# 1312 INFO: Using Python shared library: C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\python312.dll
# 1312 INFO: Running Analysis Analysis-00.toc
# 1312 INFO: Target bytecode optimization level: 0
# 1312 INFO: Initializing module dependency graph...
# 1315 INFO: Initializing module graph hook caches...
# 1342 INFO: Analyzing modules for base_library.zip ...
# 3582 INFO: Processing standard module hook 'hook-heapq.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 4166 INFO: Processing standard module hook 'hook-encodings.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 10749 INFO: Processing standard module hook 'hook-pickle.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 14570 INFO: Caching module dependency graph...
# 14700 INFO: Analyzing c:\Users\fernando.cremm\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Curso Python1\Aula 04\projeto.py
# 14998 INFO: Processing standard module hook 'hook-platform.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 15069 INFO: Processing pre-find-module-path hook 'hook-tkinter.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path'
# 15071 INFO: TclTkInfo: initializing cached Tcl/Tk info...
# 15919 INFO: Processing standard module hook 'hook-_tkinter.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 15970 INFO: Processing standard module hook 'hook-_ctypes.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 16019 INFO: Processing standard module hook 'hook-PIL.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 16203 INFO: Processing standard module hook 'hook-PIL.Image.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 17112 INFO: Processing standard module hook 'hook-xml.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 17120 INFO: Processing standard module hook 'hook-xml.etree.cElementTree.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 17296 INFO: Processing standard module hook 'hook-xml.dom.domreg.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 18781 INFO: Processing standard module hook 'hook-sysconfig.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 19231 INFO: Processing standard module hook 'hook-PIL.ImageFilter.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 20418 INFO: Processing standard module hook 'hook-difflib.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 21675 INFO: Processing standard module hook 'hook-multiprocessing.util.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# C:\Users\fernando.cremm\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Curso Python1\Aula 01\.venv\Lib\site-packages\pyautogui\_pyautogui_x11.py:284: SyntaxWarning: invalid escape sequence '\e'
#   '\e': _display.keysym_to_keycode(Xlib.XK.string_to_keysym('Escape')),
# 23589 INFO: Processing standard module hook 'hook-urllib3.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 23786 INFO: Processing pre-safe-import-module hook 'hook-backports.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 23787 INFO: SetuptoolsInfo: initializing cached setuptools info...
# 24755 INFO: Setuptools: 'backports' appears to be a full setuptools-vendored copy - creating alias to 'setuptools._vendor.backports'!
# 24767 INFO: Processing standard module hook 'hook-setuptools.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 24793 INFO: Processing pre-safe-import-module hook 'hook-distutils.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 24849 INFO: Processing pre-safe-import-module hook 'hook-jaraco.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 24849 INFO: Setuptools: 'jaraco' appears to be a full setuptools-vendored copy - creating alias to 'setuptools._vendor.jaraco'!
# 24872 INFO: Processing pre-safe-import-module hook 'hook-more_itertools.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 24873 INFO: Setuptools: 'more_itertools' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.more_itertools'!
# 25110 INFO: Processing pre-safe-import-module hook 'hook-typing_extensions.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 25492 INFO: Processing pre-safe-import-module hook 'hook-packaging.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 26076 INFO: Processing standard module hook 'hook-setuptools._vendor.jaraco.text.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 26080 INFO: Processing pre-safe-import-module hook 'hook-importlib_resources.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 26421 INFO: Processing pre-safe-import-module hook 'hook-importlib_metadata.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 26422 INFO: Setuptools: 'importlib_metadata' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.importlib_metadata'!
# 26472 INFO: Processing standard module hook 'hook-setuptools._vendor.importlib_metadata.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 26520 INFO: Processing pre-safe-import-module hook 'hook-zipp.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 26520 INFO: Setuptools: 'zipp' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.zipp'!
# 26977 INFO: Processing pre-safe-import-module hook 'hook-tomli.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 26978 INFO: Setuptools: 'tomli' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.tomli'!
# 27784 INFO: Processing pre-safe-import-module hook 'hook-wheel.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 27784 INFO: Setuptools: 'wheel' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.wheel'!
# 28522 INFO: Processing standard module hook 'hook-charset_normalizer.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 28801 INFO: Processing standard module hook 'hook-certifi.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 31652 INFO: Processing standard module hook 'hook-jinja2.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 32236 INFO: Processing pre-safe-import-module hook 'hook-win32com.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\pre_safe_import_module'
# 32469 INFO: Processing standard module hook 'hook-win32com.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 32471 INFO: Processing standard module hook 'hook-pythoncom.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 32676 INFO: Processing standard module hook 'hook-pywintypes.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 33217 INFO: Processing module hooks (post-graph stage)...
# 33585 INFO: Processing standard module hook 'hook-PIL.SpiderImagePlugin.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 33829 INFO: Processing standard module hook 'hook-_tkinter.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks'
# 33844 INFO: Performing binary vs. data reclassification (939 entries)
# 34347 INFO: Looking for ctypes DLLs
# 34406 INFO: Analyzing run-time hooks ...
# 34409 INFO: Including run-time hook 'pyi_rth_inspect.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 34412 INFO: Including run-time hook 'pyi_rth_pywintypes.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\rthooks'
# 34414 INFO: Including run-time hook 'pyi_rth_pythoncom.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\rthooks'
# 34416 INFO: Including run-time hook 'pyi_rth_pkgutil.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 34417 INFO: Including run-time hook 'pyi_rth_multiprocessing.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 34420 INFO: Including run-time hook 'pyi_rth_setuptools.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 34422 INFO: Including run-time hook 'pyi_rth__tkinter.py' from 'C:\\Users\\fernando.cremm\\OneDrive - JADLOG LOGISTICA LTDA\\Área de Trabalho\\Curso Python1\\Aula 01\\.venv\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 34476 INFO: Creating base_library.zip...
# 34514 INFO: Looking for dynamic libraries
# 37364 INFO: Extra DLL search directories (AddDllDirectory): []
# 37364 INFO: Extra DLL search directories (PATH): []
# 38074 INFO: Warnings written to c:\Users\fernando.cremm\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Curso Python1\Aula 04\build\projeto\warn-projeto.txt
# 38171 INFO: Graph cross-reference written to c:\Users\fernando.cremm\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Curso Python1\Aula 04\build\projeto\xref-projeto.html
# 38240 INFO: checking PYZ
# 38240 INFO: Building PYZ because PYZ-00.toc is non existent
# 38240 INFO: Building PYZ (ZlibArchive) c:\Users\fernando.cremm\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Curso Python1\Aula 04\build\projeto\PYZ-00.pyz
# 39202 INFO: Building PYZ (ZlibArchive) c:\Users\fernando.cremm\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Curso Python1\Aula 04\build\projeto\PYZ-00.pyz completed successfully.
# 39256 INFO: checking PKG
# 39257 INFO: Building PKG because PKG-00.toc is non existent
# 39257 INFO: Building PKG (CArchive) projeto.pkg
# 45306 INFO: Building PKG (CArchive) projeto.pkg completed successfully.
# 45331 INFO: Bootloader C:\Users\fernando.cremm\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Curso Python1\Aula 01\.venv\Lib\site-packages\PyInstaller\bootloader\Windows-64bit-intel\run.exe
# 45331 INFO: checking EXE
# 45331 INFO: Building EXE because EXE-00.toc is non existent
# 45331 INFO: Building EXE from EXE-00.toc
# 45331 INFO: Copying bootloader EXE to c:\Users\fernando.cremm\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Curso Python1\Aula 04\dist\projeto.exe
# 45346 INFO: Copying icon to EXE
# 45359 INFO: Copying 0 resources to EXE
# 45359 INFO: Embedding manifest in EXE
# 45369 INFO: Appending PKG archive to EXE
# 45405 INFO: Fixing EXE headers
# 46054 INFO: Building EXE from EXE-00.toc completed successfully.
# 46077 INFO: Build complete! The results are available in: c:\Users\fernando.cremm\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Curso Python1\Aula 04\dist
